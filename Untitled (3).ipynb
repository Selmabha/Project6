# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score

b = pd.read_csv("titanicc.csv")

# %%
b.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
b.isnull().sum()
# Out:
# pclass          1
# survived        1
# name            1
# sex             1
# age           264
# sibsp           1
# parch           1
# ticket          1
# fare            2
# cabin        1015
# embarked        3
# boat          824
# body         1189
# home.dest     565
# dtype: int64

# %%
b=b.dropna(thresh=11)

# %%
b.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 875 entries, 0 to 1306
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     875 non-null    float64
#  1   survived   875 non-null    float64
#  2   name       875 non-null    object
#  3   sex        875 non-null    object
#  4   age        839 non-null    float64
#  5   sibsp      875 non-null    float64
#  6   parch      875 non-null    float64
#  7   ticket     875 non-null    object
#  8   fare       875 non-null    float64
#  9   cabin      291 non-null    object
#  10  embarked   873 non-null    object
#  11  boat       445 non-null    object
#  12  body       119 non-null    float64
#  13  home.dest  720 non-null    object
# dtypes: float64(7), object(7)
# memory usage: 102.5+ KB

# %%
b["age"].fillna(b["age"].mean(),inplace=True)

# %%
b
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1296     3.0       0.0                                 Wirz, Mr. Albert
# 1299     3.0       0.0                              Yasbeck, Mr. Antoni
# 1301     3.0       0.0                             Youseff, Mr. Gerious
# 1304     3.0       0.0                             Zabour, Miss. Hileni
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
b["fare"].fillna(b["fare"].mean(),inplace=True)

# %%
b.isnull().sum()
# Out:
# pclass         0
# survived       0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin        584
# embarked       2
# boat         430
# body         756
# home.dest    155
# dtype: int64

# %%
b["cabin"].value_counts()
# Out:
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F4                 4
# C78                4
#                   ..
# E52                1
# B80                1
# A14                1
# A7                 1
# B3                 1
# Name: cabin, Length: 182, dtype: int64

# %%
b["cabin"].fillna('C22',inplace=True)

# %%
b
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1296     3.0       0.0                                 Wirz, Mr. Albert
# 1299     3.0       0.0                              Yasbeck, Mr. Antoni
# 1301     3.0       0.0                             Youseff, Mr. Gerious
# 1304     3.0       0.0                             Zabour, Miss. Hileni
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
b["embarked"].fillna('S',inplace=True)

# %%
b.isnull().sum()
# Out:
# pclass         0
# survived       0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin          0
# embarked       0
# boat         430
# body         756
# home.dest    155
# dtype: int64

# %%
b["home.dest"].fillna('New York, NY',inplace=True)

# %%
b.isnull().sum()
# Out:
# pclass         0
# survived       0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin          0
# embarked       0
# boat         430
# body         756
# home.dest      0
# dtype: int64

# %%
b
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1296     3.0       0.0                                 Wirz, Mr. Albert
# 1299     3.0       0.0                              Yasbeck, Mr. Antoni
# 1301     3.0       0.0                             Youseff, Mr. Gerious
# 1304     3.0       0.0                             Zabour, Miss. Hileni
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
b.drop(['boat'],1,inplace=True)

# %%
b.isnull().sum()
# Out:
# pclass         0
# survived       0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin          0
# embarked       0
# body         756
# home.dest      0
# dtype: int64

# %%
b.isnull().sum()
# Out:
# pclass         0
# survived       0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin          0
# embarked       0
# body         756
# home.dest      0
# dtype: int64

# %%
b.drop("body",1,inplace=True)

# %%
b.isnull().sum()
# Out:
# pclass       0
# survived     0
# name         0
# sex          0
# age          0
# sibsp        0
# parch        0
# ticket       0
# fare         0
# cabin        0
# embarked     0
# home.dest    0
# dtype: int64

# %%
b.pivot_table('survived',index='age',columns='sex',aggfunc="sum").plot()

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
plot_correlation_map (b)

# %%
b.isnull().sum()
# Out:
# pclass       0
# survived     0
# name         0
# sex          0
# age          0
# sibsp        0
# parch        0
# ticket       0
# fare         0
# cabin        0
# embarked     0
# home.dest    0
# dtype: int64

# %%
Liste=[]
df1=''
for data in b["name"]:
    df1=data.split(",")
    df1=df1[1].split(".")
    df2=df1[0].strip()
    Liste.append((df2))
b["Title"]=Liste

# %%
b.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S
#
#                          home.dest   Title
# 0                     St Louis, MO    Miss
# 1  Montreal, PQ / Chesterville, ON  Master
# ...

# %%
b[['pclass','survived']].groupby(['pclass'],as_index=True).mean()
# Out:
#         survived
# pclass
# 1.0     0.641935
# 2.0     0.461240
# 3.0     0.423453

# %%
    sns.factorplot('sex',data=b,kind="count",hue='Title')
# Out:
# c:\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
Title_Dictionary = {

                    "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                      "Dr":         "Officer",

                    "Rev":        "Officer",

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",

                   "Lady" :      "Royalty",

                  "the Countess": "Royalty",

                    "Dona":       "Royalty" ,

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs",

                    "Master" :    "Master"

                    }
b["Title"].str.strip()
# Out:
# 0         Miss
# 1       Master
# 2         Miss
# 3           Mr
# 4          Mrs
#          ...
# 1296        Mr
# 1299        Mr
# 1301        Mr
# 1304      Miss
# 1306        Mr
# Name: Title, Length: 875, dtype: object

# %%
b["Title"]=b["Title"].str.strip()

# %%
b["Title"].replace(Title_Dictionary,inplace=True)

# %%
b["Title"].values
# Out:
# array(['Miss', 'Master', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs',
#        'Mrs', 'Mrs', 'Officer', 'Mrs', 'Miss', 'Miss', 'Mrs', 'Mrs',
#        'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Mrs',
#        'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Mrs',
#        'Miss', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss',
#        'Officer', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Master', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Miss', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Officer',
#        'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Officer', 'Master', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Royalty', 'Royalty', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Miss', 'Mrs',
#        'Mrs', 'Mrs', 'Miss', 'Miss', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Miss',
# ...

# %%
b.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S
#
#                          home.dest   Title
# 0                     St Louis, MO    Miss
# 1  Montreal, PQ / Chesterville, ON  Master
# ...

# %%
sns.factorplot('sex',data=b,kind="count",hue='Title')
# Out:
# c:\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
x=pd.DataFrame()
x["Family"]=b["sibsp"]+b["parch"]

x
# Out:
#       Family
# 0        0.0
# 1        3.0
# 2        3.0
# 3        3.0
# 4        3.0
# ...      ...
# 1296     0.0
# 1299     1.0
# 1301     0.0
# 1304     1.0
# 1306     0.0
#
# [875 rows x 1 columns]

# %%
b["Family"]=x

# %%
b.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S
#
#                          home.dest   Title  Family
# 0                     St Louis, MO    Miss     0.0
# ...

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 875 entries, 0 to 1306
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     875 non-null    float64
#  1   survived   875 non-null    float64
#  2   name       875 non-null    object
#  3   sex        875 non-null    object
#  4   age        875 non-null    float64
#  5   sibsp      875 non-null    float64
#  6   parch      875 non-null    float64
#  7   ticket     875 non-null    object
#  8   fare       875 non-null    float64
#  9   cabin      875 non-null    object
#  10  embarked   875 non-null    object
#  11  home.dest  875 non-null    object
#  12  Title      875 non-null    object
#  13  Family     875 non-null    float64
# dtypes: float64(7), object(7)
# memory usage: 142.5+ KB

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
b['name']=encoder.fit_transform(b['name'])
b.head()
# Out:
#    pclass  survived  name     sex      age  sibsp  parch  ticket      fare  \
# 0     1.0       1.0    19  female  29.0000    0.0    0.0   24160  211.3375
# 1     1.0       1.0    21    male   0.9167    1.0    2.0  113781  151.5500
# 2     1.0       0.0    22  female   2.0000    1.0    2.0  113781  151.5500
# 3     1.0       0.0    23    male  30.0000    1.0    2.0  113781  151.5500
# 4     1.0       0.0    24  female  25.0000    1.0    2.0  113781  151.5500
#
#      cabin embarked                        home.dest   Title  Family
# 0       B5        S                     St Louis, MO    Miss     0.0
# 1  C22 C26        S  Montreal, PQ / Chesterville, ON  Master     3.0
# 2  C22 C26        S  Montreal, PQ / Chesterville, ON    Miss     3.0
# 3  C22 C26        S  Montreal, PQ / Chesterville, ON     Mrs     3.0
# 4  C22 C26        S  Montreal, PQ / Chesterville, ON     Mrs     3.0

# %%
cleanup_nums={ "female": 1, "male": 0
}
b.replace(cleanup_nums, inplace=True)
b
# Out:
#       pclass  survived  name  sex      age  sibsp  parch  ticket      fare  \
# 0        1.0       1.0    19    1  29.0000    0.0    0.0   24160  211.3375
# 1        1.0       1.0    21    0   0.9167    1.0    2.0  113781  151.5500
# 2        1.0       0.0    22    1   2.0000    1.0    2.0  113781  151.5500
# 3        1.0       0.0    23    0  30.0000    1.0    2.0  113781  151.5500
# 4        1.0       0.0    24    1  25.0000    1.0    2.0  113781  151.5500
# ...      ...       ...   ...  ...      ...    ...    ...     ...       ...
# 1296     3.0       0.0   856    0  27.0000    0.0    0.0  315154    8.6625
# 1299     3.0       0.0   860    0  27.0000    1.0    0.0    2659   14.4542
# 1301     3.0       0.0   862    0  45.5000    0.0    0.0    2628    7.2250
# 1304     3.0       0.0   864    1  14.5000    1.0    0.0    2665   14.4542
# 1306     3.0       0.0   865    0  26.5000    0.0    0.0    2656    7.2250
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
b['ticket']=encoder.fit_transform(b['ticket'])
b.head()
# Out:
#    pclass  survived  name  sex      age  sibsp  parch  ticket      fare  \
# 0     1.0       1.0    19    1  29.0000    0.0    0.0     169  211.3375
# 1     1.0       1.0    21    0   0.9167    1.0    2.0      46  151.5500
# 2     1.0       0.0    22    1   2.0000    1.0    2.0      46  151.5500
# 3     1.0       0.0    23    0  30.0000    1.0    2.0      46  151.5500
# 4     1.0       0.0    24    1  25.0000    1.0    2.0      46  151.5500
#
#      cabin embarked                        home.dest   Title  Family
# 0       B5        S                     St Louis, MO    Miss     0.0
# 1  C22 C26        S  Montreal, PQ / Chesterville, ON  Master     3.0
# 2  C22 C26        S  Montreal, PQ / Chesterville, ON    Miss     3.0
# 3  C22 C26        S  Montreal, PQ / Chesterville, ON     Mrs     3.0
# 4  C22 C26        S  Montreal, PQ / Chesterville, ON     Mrs     3.0

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
b['cabin']=encoder.fit_transform(b['cabin'])
b.head()
# Out:
#    pclass  survived  name  sex      age  sibsp  parch  ticket      fare  \
# 0     1.0       1.0    19    1  29.0000    0.0    0.0     169  211.3375
# 1     1.0       1.0    21    0   0.9167    1.0    2.0      46  151.5500
# 2     1.0       0.0    22    1   2.0000    1.0    2.0      46  151.5500
# 3     1.0       0.0    23    0  30.0000    1.0    2.0      46  151.5500
# 4     1.0       0.0    24    1  25.0000    1.0    2.0      46  151.5500
#
#    cabin embarked                        home.dest   Title  Family
# 0     42        S                     St Louis, MO    Miss     0.0
# 1     79        S  Montreal, PQ / Chesterville, ON  Master     3.0
# 2     79        S  Montreal, PQ / Chesterville, ON    Miss     3.0
# 3     79        S  Montreal, PQ / Chesterville, ON     Mrs     3.0
# 4     79        S  Montreal, PQ / Chesterville, ON     Mrs     3.0

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
b['embarked']=encoder.fit_transform(b['embarked'])
b.head()
# Out:
#    pclass  survived  name  sex      age  sibsp  parch  ticket      fare  \
# 0     1.0       1.0    19    1  29.0000    0.0    0.0     169  211.3375
# 1     1.0       1.0    21    0   0.9167    1.0    2.0      46  151.5500
# 2     1.0       0.0    22    1   2.0000    1.0    2.0      46  151.5500
# 3     1.0       0.0    23    0  30.0000    1.0    2.0      46  151.5500
# 4     1.0       0.0    24    1  25.0000    1.0    2.0      46  151.5500
#
#    cabin  embarked                        home.dest   Title  Family
# 0     42         2                     St Louis, MO    Miss     0.0
# 1     79         2  Montreal, PQ / Chesterville, ON  Master     3.0
# 2     79         2  Montreal, PQ / Chesterville, ON    Miss     3.0
# 3     79         2  Montreal, PQ / Chesterville, ON     Mrs     3.0
# 4     79         2  Montreal, PQ / Chesterville, ON     Mrs     3.0

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
b['home.dest']=encoder.fit_transform(b['home.dest'])
b.head()
# Out:
#    pclass  survived  name  sex      age  sibsp  parch  ticket      fare  \
# 0     1.0       1.0    19    1  29.0000    0.0    0.0     169  211.3375
# 1     1.0       1.0    21    0   0.9167    1.0    2.0      46  151.5500
# 2     1.0       0.0    22    1   2.0000    1.0    2.0      46  151.5500
# 3     1.0       0.0    23    0  30.0000    1.0    2.0      46  151.5500
# 4     1.0       0.0    24    1  25.0000    1.0    2.0      46  151.5500
#
#    cabin  embarked  home.dest   Title  Family
# 0     42         2        302    Miss     0.0
# 1     79         2        225  Master     3.0
# 2     79         2        225    Miss     3.0
# 3     79         2        225     Mrs     3.0
# 4     79         2        225     Mrs     3.0

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
b['Title']=encoder.fit_transform(b['Title'])
b.head()
# Out:
#    pclass  survived  name  sex      age  sibsp  parch  ticket      fare  \
# 0     1.0       1.0    19    1  29.0000    0.0    0.0     169  211.3375
# 1     1.0       1.0    21    0   0.9167    1.0    2.0      46  151.5500
# 2     1.0       0.0    22    1   2.0000    1.0    2.0      46  151.5500
# 3     1.0       0.0    23    0  30.0000    1.0    2.0      46  151.5500
# 4     1.0       0.0    24    1  25.0000    1.0    2.0      46  151.5500
#
#    cabin  embarked  home.dest  Title  Family
# 0     42         2        302      1     0.0
# 1     79         2        225      0     3.0
# 2     79         2        225      1     3.0
# 3     79         2        225      2     3.0
# 4     79         2        225      2     3.0

# %%
x=b[["name", "sex", "age", "sibsp","parch","ticket","fare","cabin","embarked","home.dest","Family","Title"]]
y=b["survived"]

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=40) #splitting data with test size of 35%

logreg = LogisticRegression()   #build our logistic model
logreg.fit(x_train, y_train)  #fitting training data
y_pred  = logreg.predict(x_test)    #testing model’s performance
print("Accuracy={:.2f}".format(logreg.score(x_test, y_test)))
# Out:
# Accuracy=0.79
# c:\python3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
import seaborn as sns
sns.regplot(x='age',y='survived',data=b,logistic=True)

# %%
confusion_matrix=pd.crosstab(y_test,y_pred, rownames=['actual'],colnames=['predicted'])
print(confusion_matrix)
# Out:
# predicted  0.0  1.0
# actual
# 0.0         76   12
# 1.0         24   63

# %%
fpr, tpr,_=roc_curve(logreg.predict(x),y,drop_intermediate=False)
import matplotlib.pyplot as plt
plt.figure(figsize=(7, 7))
plt.plot(fpr, tpr, color='red',
 lw=2, label='ROC curve')
plt.plot([0, 1], [0, 1], color='blue', lw=2, linestyle='--')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC curve')
plt.show()

# %%
import sklearn.metrics as metrics
# calculate the fpr and tpr for all thresholds of the classification
probs = logreg.predict_proba(x_test)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

# method I: plt
import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# l'allure de la courbe se rapproche de l'axe des ordonnées. Les données de la data sont correctes

# %%
#features extraction
from sklearn import tree
x=b[["name", "sex", "age", "sibsp","parch","ticket","fare","cabin","embarked","home.dest"]]
y=b["survived"]

#splitting data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)

#applying tree algorithm
treee = tree.DecisionTreeClassifier()  
treee.fit(x_train, y_train)   #fitting our model
y_pred=treee.predict(x_test)   # evaluating our model
treee.score(x_test,y_test)
# Out:
# 0.7371428571428571

# %%
#connaitre le meilleur estimator 
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
random_grid = {'n_estimators': n_estimators,}

param_grid = {
    'n_estimators': [100, 200, 300, 1000]
}
rf = RandomForestRegressor()
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 3, n_jobs = -1, verbose = 2)
grid_search.fit(x_train, y_train)
grid_search.best_params_
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of  12 | elapsed:    4.0s remaining:    8.0s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    8.3s finished
# {'n_estimators': 300}

# %%
#features extraction
from sklearn.ensemble import RandomForestClassifier 
x=b[["name", "sex", "age", "sibsp","parch","ticket","fare","cabin","embarked","home.dest"]]
y=b["survived"]

#splitting data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)

#applying tree algorithm
tree = RandomForestClassifier(n_estimators=200)  
tree.fit(x_train, y_train)   #fitting our model
y_pred=tree.predict(x_test)   # evaluating our model
tree.score(x_test,y_test)
# Out:
# 0.8285714285714286

# %%
pip install graphiz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Could not find a version that satisfies the requirement graphiz (from versions: none)
# ERROR: No matching distribution found for graphiz
# WARNING: You are using pip version 19.2.3, however version 20.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# !pip -q install pydot_ng
# !pip -q install graphviz
# !apt install graphviz > /dev/null
# Out:
# WARNING: You are using pip version 19.2.3, however version 20.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# WARNING: You are using pip version 19.2.3, however version 20.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Le chemin d'accŠs sp‚cifi‚ est introuvable.
